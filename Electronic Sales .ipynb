# %% [markdown]
# ### Importing Libraries :-

# %%
import pandas as pd
import numpy as np

# %%
cust.shape
# Out:
# (15266, 10)

# %%
sales.shape
# Out:
# (62884, 10)

# %%
product.shape
# Out:
# (2517, 10)

# %%
Stores.shape
# Out:
# (67, 5)

# %%
sales['Order Number'].unique
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order Number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sales['Order Number'].unique
#
# ...

# %% [markdown]
# ### LOADING THE DATASET:-

# %% [markdown]
# #### Customers Data :-

# %%
cust = pd.read_csv(r"C:\Users\Rohit kumar\Downloads\Customers.csv",encoding='utf-8', encoding_errors='replace')
cust.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  07-03-1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965

# %% [markdown]
# #### Sales Data :-

# %%
sales = pd.read_csv(r"C:\Users\Rohit kumar\Downloads\Sales.csv")
sales.head()
# Out:
#    OrderNumber  LineItem   OrderDate DeliveryDate  CustomerKey  StoreKey  \
# 0       366000         1  01-01-2016          NaN       265598        10
# 1       366001         1  01-01-2016   13-01-2016      1269051         0
# 2       366001         2  01-01-2016   13-01-2016      1269051         0
# 3       366002         1  01-01-2016   12-01-2016       266019         0
# 4       366002         2  01-01-2016   12-01-2016       266019         0
#
#    ProductKey  Quantity Currency Code      StoreMode
# 0        1304         1           CAD  Offline Store
# 1        1048         2           USD    Online Mode
# 2        2007         1           USD    Online Mode
# 3        1106         7           CAD    Online Mode
# 4         373         1           CAD    Online Mode

# %% [markdown]
# #### Product Data :-

# %%
product = pd.read_csv(r"C:\Users\Rohit kumar\Downloads\Products.csv")
product.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %% [markdown]
# #### Exchange Rate Data :-

# %%
Exchange = pd.read_csv(r"C:\Users\Rohit kumar\Downloads\Exchange_Rates.csv")
Exchange.head()
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %% [markdown]
# #### Stores Data :-

# %%
Stores = pd.read_csv(r"C:\Users\Rohit kumar\Downloads\Stores.csv")
Stores.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0   1/1/2008
# 1         2  Australia            Northern Territory          665.0  1/12/2008
# 2         3  Australia               South Australia         2000.0   1/7/2012
# 3         4  Australia                      Tasmania         2000.0   1/1/2010
# 4         5  Australia                      Victoria         2000.0  12/9/2015

# %% [markdown]
# ### 1). EDA on Customers Table:-

# %%
cust.shape
# Out:
# (15266, 10)

# %%
cust.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  07-03-1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965

# %%
cust.sample(5)
# Out:
#        CustomerKey  Gender             Name               City State Code  \
# 10650      1489650    Male   Albert Merritt           Fairport         NY
# 148          21523    Male    Jayden Rennie          SWANHAVEN        NSW
# 8921       1263974  Female  Elizabeth Billy  Fort Walton Beach         FL
# 9517       1344122  Female  Jessica Jenkins             Archer         FL
# 7644       1081249  Female      Laura Kirby         ACHNACLYTH   Highland
#
#                  State Zip Code         Country      Continent    Birthday
# 10650         New York    14450   United States  North America  11-06-1988
# 148    New South Wales     2540       Australia      Australia  12-06-1969
# 8921           Florida    32547   United States  North America  09-06-1970
# 9517           Florida    32618   United States  North America  12/27/1989
# 7644          Highland  KW6 2LN  United Kingdom         Europe   1/24/1967

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
cust.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_rows', None)

# %%
# cust.groupby('State')['State Code'].unique()

# %% [markdown]
# #### 🧐Check In which rows we have nan value :-

# %%
cust[cust.isnull().any(axis=1)]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %% [markdown]
# ##### 👉 Only Napoli state code is missing so i replace it with NL because only one state cose is missing

# %% [markdown]
# #### 🛠️ Fix the NaN in the State Code:-

# %%
cust['State Code'] = cust['State Code'].fillna('NL')

# %%
# Check the nan value 
cust.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
####✔️ Check the Napoli column
cust[cust['State'] == 'Napoli']
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica         NL
# 5316       732289    Male        Indro Piccio          Varcaturo         NL
# 5372       742042    Male     Amaranto Loggia          Casaferro         NL
# 5377       742886  Female       Edmonda Capon           Terzigno         NL
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco         NL
# 5485       759705    Male    Callisto Lo Duca            Casilli         NL
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi         NL
# 5531       766410    Male   Adelmio Beneventi             Licola         NL
# 5631       781667  Female          Ilda Manna             Napoli         NL
# 5695       789177    Male   Calogero Folliero      Mariglianella         NL
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
cust.columns
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State',
#        'Zip Code', 'Country', 'Continent', 'Birthday'],
#       dtype='object')

# %% [markdown]
# ### Remove Incosistency in names columns:-

# %% [markdown]
# ##### 🧹 Removes � from the Name column

# %%
# Check the

# %%
cust['Name'] = cust['Name'].str.replace('�',"")
cust['City'] = cust['City'].str.replace('�',"")
cust['State'] = cust['State'].str.replace('�',"")

# %%
cust[cust['CustomerKey'] == 2099600]
# Out:
#        CustomerKey  Gender          Name     City State Code  State Zip Code  \
# 15261      2099600  Female  Denisa Dukov  Houston         TX  Texas    77017
#
#              Country      Continent   Birthday
# 15261  United States  North America  3-25-1936

# %%
cust[cust['CustomerKey'] == 454932]
# Out:
#       CustomerKey  Gender             Name    City State Code  \
# 3393       454932  Female  Christin Fuerst  Mnchen         BY
#
#                  State Zip Code  Country Continent   Birthday
# 3393  Freistaat Bayern    80741  Germany    Europe  3-13-1985

# %% [markdown]
# #### Fix country and continent

# %%
cust.groupby('Country')['Continent'].unique()
# Out:
# Country
# Australia               [Oceania]
# Canada            [North America]
# France                   [Europe]
# Germany                  [Europe]
# Italy                    [Europe]
# Netherlands              [Europe]
# United Kingdom           [Europe]
# United States     [North America]
# Name: Continent, dtype: object

# %%
cust['Country'].unique().tolist()
# Out:
# ['Australia',
#  'Canada',
#  'Germany',
#  'France',
#  'Italy',
#  'Netherlands',
#  'United Kingdom',
#  'United States']

# %% [markdown]
# #### Fix the Australia columns its continent should be Oceania :-

# %%
cust[cust['Country']== 'Australia'].head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country Continent    Birthday
# 0    South Australia     5523  Australia   Oceania  07-03-1939
# 1  Western Australia     6522  Australia   Oceania   9-27-1979
# 2           Victoria     3380  Australia   Oceania   5-26-1947
# 3    South Australia     5223  Australia   Oceania   9-17-1957
# 4           Victoria     3698  Australia   Oceania  11-19-1965

# %%
cust.loc[cust['Country']== 'Australia','Continent'] = 'Oceania'

# %%
# Fix the Australia Ocean :-
cust[cust['Country']== 'Australia'].head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country Continent    Birthday
# 0    South Australia     5523  Australia   Oceania  07-03-1939
# 1  Western Australia     6522  Australia   Oceania   9-27-1979
# 2           Victoria     3380  Australia   Oceania   5-26-1947
# 3    South Australia     5223  Australia   Oceania   9-17-1957
# 4           Victoria     3698  Australia   Oceania  11-19-1965

# %% [markdown]
# #### 🛠️ Fix the  data types of all columns:-

# %%
# Check the data types:-
cust.dtypes
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %% [markdown]
# ##### 👉 There is one columns in which data types is wrong :-
#   ###### 1)-Birthday

# %% [markdown]
# ##### 1) Birthday :-

# %%
cust['Birthday'].dtypes
# Out:
# dtype('O')

# %%
cust['Birthday'].unique()
# Out:
# array(['07-03-1939', '9-27-1979', '5-26-1947', ..., '3-25-1936',
#        '11-09-1937', '8-18-1965'], dtype=object)

# %%
## Chnage the date column into date dtypes 
# cust['Birthday'] = pd.to_datetime(cust['Birthday'],errors = 'coerce')

# %%
cust['Birthday'] = cust['Birthday'].str.replace("/","-")

# %%
cust[cust['CustomerKey']== 1568]
# Out:
#    CustomerKey Gender         Name   City State Code     State Zip Code  \
# 9         1568   Male  Luke Virtue  KOTTA        VIC  Victoria     3565
#
#      Country Continent   Birthday
# 9  Australia   Oceania  7-25-1975

# %%
cust[cust['CustomerKey']== 1314]
# Out:
#    CustomerKey Gender          Name         City State Code  \
# 8         1314   Male  Isaac Israel  EDITH RIVER         NT
#
#                 State Zip Code    Country Continent    Birthday
# 8  Northern Territory      852  Australia   Oceania  12-21-1965

# %%
cust['Birthday'].unique()
# Out:
# array(['07-03-1939', '9-27-1979', '5-26-1947', ..., '3-25-1936',
#        '11-09-1937', '8-18-1965'], dtype=object)

# %%
cust.sample(10)
# Out:
#        CustomerKey  Gender               Name          City State Code  \
# 11673      1624311    Male     Eugene Morales  Indianapolis         IN
# 4613        624293  Female   Fanchon Bourassa  SAINT-PRIEST         RA
# 2876        387530    Male       Kevin Houser       Orillia         ON
# 5293        728022  Female    Jolanda  Milani   Castellazzo         RE
# 12708      1756921  Female      Sarah Luckett       Spokane         WA
# 8751       1242050  Female  Marketta Thompson    Southfield         MI
# 12133      1686814    Male     George Shirley     Lexington         KY
# 590          85220    Male       Levi Prenzel        KOOJAN         WA
# 1638        227416    Male      Michael Hicks      Red Deer         AB
# 12430      1722247    Male         James Sosa       Tremont         PA
#
#                    State Zip Code        Country      Continent    Birthday
# 11673            Indiana    46254  United States  North America  01-01-1960
# ...

# %%
cust['Birthday'].unique()
# Out:
# array(['07-03-1939', '9-27-1979', '5-26-1947', ..., '3-25-1936',
#        '11-09-1937', '8-18-1965'], dtype=object)

# %%
cust['Birthday'].dtypes
# Out:
# dtype('O')

# %%
cust['Birthday'] = pd.to_datetime(cust['Birthday'])

# %%
cust['Birthday'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
cust.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
## Check the date columns:-
cust['Birthday'].head()
# Out:
# 0   1939-07-03
# 1   1979-09-27
# 2   1947-05-26
# 3   1957-09-17
# 4   1965-11-19
# Name: Birthday, dtype: datetime64[ns]

# %%
cust['Birthday'].unique()
# Out:
# <DatetimeArray>
# ['1939-07-03 00:00:00', '1979-09-27 00:00:00', '1947-05-26 00:00:00',
#  '1957-09-17 00:00:00', '1965-11-19 00:00:00', '1954-01-20 00:00:00',
#  '1969-11-22 00:00:00', '1950-03-12 00:00:00', '1965-12-21 00:00:00',
#  '1975-07-25 00:00:00',
#  ...
#  '1951-10-31 00:00:00', '1937-10-09 00:00:00', '2002-02-18 00:00:00',
#  '1939-12-13 00:00:00', '1987-11-02 00:00:00', '1971-12-02 00:00:00',
#  '2001-01-27 00:00:00', '1936-03-25 00:00:00', '1937-11-09 00:00:00',
#  '1965-08-18 00:00:00']
# Length: 11270, dtype: datetime64[ns]

# %%
cust[cust['CustomerKey']== 1568]
# Out:
#    CustomerKey Gender         Name   City State Code     State Zip Code  \
# 9         1568   Male  Luke Virtue  KOTTA        VIC  Victoria     3565
#
#      Country Continent   Birthday
# 9  Australia   Oceania 1975-07-25

# %%
cust.head(10)
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
# 5         1086    Male       Hayden Clegg        TEMPLERS         SA
# 6         1133    Male    Nicholas Caffyn  JUBILEE POCKET        QLD
# 7         1256    Male      Lincoln Jenks        KULLOGUM        QLD
# 8         1314    Male       Isaac Israel     EDITH RIVER         NT
# 9         1568    Male        Luke Virtue           KOTTA        VIC
#
#                 State Zip Code    Country Continent   Birthday
# 0     South Australia     5523  Australia   Oceania 1939-07-03
# 1   Western Australia     6522  Australia   Oceania 1979-09-27
# ...

# %%
cust.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
cust.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country Continent   Birthday
# 0    South Australia     5523  Australia   Oceania 1939-07-03
# 1  Western Australia     6522  Australia   Oceania 1979-09-27
# 2           Victoria     3380  Australia   Oceania 1947-05-26
# 3    South Australia     5223  Australia   Oceania 1957-09-17
# 4           Victoria     3698  Australia   Oceania 1965-11-19

# %%
cust.to_csv(r'C:\Users\Rohit kumar\Downloads\customer.csv')

# %%
# 1086	Male	Hayden Clegg	TEMPLERS	SA	South Australia	5371	Australia	Australia	NaT
# 6	1133	Male	Nicholas Caffyn	JUBILEE POCKET	QLD	Queensland	4802	Australia	Australia	NaT
# 7	1256	Male	Lincoln Jenks	KULLOGUM	QLD	Queensland	4660	Australia	Australia	NaT
# 8	1314	Male	Isaac Israel	EDITH RIVER	NT	Northern Territory	852	Australia	Australia	NaT
# 9	1568

# %%
# cust[cust['Birthday'].isnull().any(axis = 0)]
cust.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %% [markdown]
# ### 2). EDA on Sales Table:-

# %%
sales.head()
# Out:
#    OrderNumber  LineItem   OrderDate DeliveryDate  CustomerKey  StoreKey  \
# 0       366000         1  01-01-2016          NaN       265598        10
# 1       366001         1  01-01-2016   13-01-2016      1269051         0
# 2       366001         2  01-01-2016   13-01-2016      1269051         0
# 3       366002         1  01-01-2016   12-01-2016       266019         0
# 4       366002         2  01-01-2016   12-01-2016       266019         0
#
#    ProductKey  Quantity Currency Code      StoreMode
# 0        1304         1           CAD  Offline Store
# 1        1048         2           USD    Online Mode
# 2        2007         1           USD    Online Mode
# 3        1106         7           CAD    Online Mode
# 4         373         1           CAD    Online Mode

# %%
sales['OrderNumber'].nunique()
# Out:
# 26326

# %%
#### Check the details informations
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
sales.shape
# Out:
# (62884, 9)

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# Delivery Date    object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %% [markdown]
# #### 🛠️ Fix the date columns data types :-

# %% [markdown]
# #### Order Date :-

# %%
sales['Order Date'].unique()
# Out:
# array(['1/1/2016', '1/2/2016', '1/3/2016', ..., '2/18/2021', '2/19/2021',
#        '2/20/2021'], dtype=object)

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'])

# %%
sales.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# Delivery Date            object
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %% [markdown]
# #### Delivery Date :-

# %%
sales['Delivery Date'] = pd.to_datetime(sales['Delivery Date'])

# %%
sales.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# Delivery Date    datetime64[ns]
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
sales.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1 2016-01-01           NaT       265598        10
# 1        366001          1 2016-01-01    2016-01-13      1269051         0
# 2        366001          2 2016-01-01    2016-01-13      1269051         0
# 3        366002          1 2016-01-01    2016-01-12       266019         0
# 4        366002          2 2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
sales['Store Mode'] = np.where(
    sales['Delivery Date'].isna(),
    'Offline Store',
    'Online Mode'
)

# %%
sales.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1 2016-01-01           NaT       265598        10
# 1        366001          1 2016-01-01    2016-01-13      1269051         0
# 2        366001          2 2016-01-01    2016-01-13      1269051         0
# 3        366002          1 2016-01-01    2016-01-12       266019         0
# 4        366002          2 2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code     Store Mode
# 0        1304         1           CAD  Offline Store
# 1        1048         2           USD    Online Mode
# 2        2007         1           USD    Online Mode
# 3        1106         7           CAD    Online Mode
# 4         373         1           CAD    Online Mode

# %%
sales.columns
# Out:
# Index(['Order Number', 'Line Item', 'Order Date', 'Delivery Date',
#        'CustomerKey', 'StoreKey', 'ProductKey', 'Quantity', 'Currency Code',
#        'Store Mode'],
#       dtype='object')

# %%
sales.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# Delivery Date    datetime64[ns]
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# Store Mode               object
# dtype: object

# %%
sales.to_csv(r'C:\Users\Rohit kumar\Downloads\sales.csv')

# %% [markdown]
# ### 3). EDA on product Table:-

# %%
product.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
product.shape
# Out:
# (2517, 10)

# %%
product.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
product.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %% [markdown]
# #### Fix the data types Unit Cost USD & Unit Price USD :-

# %% [markdown]
# #### 1). Unit Cost USD  :-

# %%
### Check the column :-
product['Unit Cost USD'].head().unique()
# Out:
# array(['$6.62 ', '$7.40 ', '$11.00 '], dtype=object)

# %% [markdown]
# #### 🧹 Remove the dolllars sign from the columns :-

# %%
product['Unit Cost USD'] = product['Unit Cost USD'].str.replace('$',"")

# %% [markdown]
# #### 💡 Change the data types :-

# %%
product['Unit Cost USD'] = product['Unit Cost USD'].str.replace(',','').str.strip().astype(float)

# %%
product['Unit Cost USD'].head().unique()
# Out:
# array([ 6.62,  7.4 , 11.  ])

# %% [markdown]
# #### 2). Unit Price  USD  :-

# %% [markdown]
# #### 🧹 Remove the dolllars sign from the columns :-

# %%
product['Unit Price USD'] = product['Unit Price USD'].str.replace('$',"")

# %% [markdown]
# #### 💡 Change the data types :-

# %%
product['Unit Price USD'] = product['Unit Price USD'].str.replace(',','').str.strip().astype(float)

# %%
product.sample(5)
# Out:
#       ProductKey                                       Product Name  \
# 760          761  Contoso USB Data Link-direct connect adapter E...
# 373          374             Adventure Works Laptop19W X1980 Silver
# 2082        2083              Contoso Microwave 0.9CuFt E0090 Black
# 1666        1667                 MGS Hand Games for kids E300 Black
# 118          119            Adventure Works 13" Color TV E25 Silver
#
#                 Brand   Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# 760           Contoso   Black           8.62           16.90             308
# 373   Adventure Works  Silver         430.38         1299.00             301
# 2082          Contoso   Black          50.98           99.99             803
# 1666    Tailspin Toys   Black           2.80            5.50             701
# 118   Adventure Works  Silver          61.17          119.99             201
#
#                 Subcategory  CategoryKey         Category
# ...

# %%
product.dtypes
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object

# %%
### Check the ',' in cost and price usd columns:-
product[product['ProductKey'] == 1882]
# Out:
#       ProductKey                            Product Name    Brand  Color  \
# 1881        1882  Contoso Washer & Dryer 27in L270 Green  Contoso  Green
#
#       Unit Cost USD  Unit Price USD  SubcategoryKey       Subcategory  \
# 1881         878.66          2652.0             801  Washers & Dryers
#
#       CategoryKey         Category
# 1881            8  Home Appliances

# %%
# 1882 ProductKey

# %%
product.to_csv(r'C:\Users\Rohit kumar\Downloads\product.csv')

# %% [markdown]
# #### Check the product name :-

# %%
product['Product Name'].nunique()
# Out:
# 2517

# %%
product['Brand'].unique()
# Out:
# array(['Contoso', 'Wide World Importers', 'Northwind Traders',
#        'Adventure Works', 'Southridge Video', 'Litware', 'Fabrikam',
#        'Proseware', 'A. Datum', 'The Phone Company', 'Tailspin Toys'],
#       dtype=object)

# %%
product.groupby('Brand')['Product Name'].unique()
# Out:
# Brand
# A. Datum                [A. Datum Compact Digital Camera M200 Black, A...
# Adventure Works         [Adventure Works 20" CRT TV E15 Silver, Advent...
# Contoso                 [Contoso 512MB MP3 Player E51 Silver, Contoso ...
# Fabrikam                [Fabrikam Laptop19W M9800 Black, Fabrikam Lapt...
# Litware                 [Litware Home Theater System 4.1 Channel M410 ...
# Northwind Traders       [NT Bluetooth Stereo Headphones E52 Blue, NT B...
# Proseware               [Proseware Laptop19 X910 Black, Proseware Lapt...
# Southridge Video        [SV 16xDVD M300 Black, SV 8xDVD E100 Black, SV...
# Tailspin Toys           [MGS Hand Games for kids E300 Yellow, MGS Hand...
# The Phone Company       [The Phone Company Touch Screen Phone 1600 TFT...
# Wide World Importers    [WWI 1GB Pulse Smart pen E50 White, WWI 1GBPul...
# Name: Product Name, dtype: object

# %%
product.groupby('Product Name')['Subcategory'].unique()
# Out:
# Product Name
# A. Datum Advanced Digital Camera M300 Azure                           [Digital Cameras]
# A. Datum Advanced Digital Camera M300 Black                           [Digital Cameras]
# A. Datum Advanced Digital Camera M300 Green                           [Digital Cameras]
# A. Datum Advanced Digital Camera M300 Grey                            [Digital Cameras]
# A. Datum Advanced Digital Camera M300 Orange                          [Digital Cameras]
#                                                                           ...
# WWI Wireless Transmitter and Bluetooth Headphones X250 Black     [Bluetooth Headphones]
# WWI Wireless Transmitter and Bluetooth Headphones X250 Blue      [Bluetooth Headphones]
# WWI Wireless Transmitter and Bluetooth Headphones X250 Red       [Bluetooth Headphones]
# WWI Wireless Transmitter and Bluetooth Headphones X250 Silver    [Bluetooth Headphones]
# WWI Wireless Transmitter and Bluetooth Headphones X250 White     [Bluetooth Headphones]
# ...

# %%
product.groupby('Category')['Subcategory'].unique()
# Out:
# Category
# Audio                               [MP4&MP3, Recording Pen, Bluetooth Headphones]
# Cameras and camcorders           [Digital Cameras, Digital SLR Cameras, Camcord...
# Cell phones                      [Home & Office Phones, Touch Screen Phones, Sm...
# Computers                        [Laptops, Desktops, Monitors, Projectors & Scr...
# Games and Toys                                       [Boxed Games, Download Games]
# Home Appliances                  [Washers & Dryers, Refrigerators, Microwaves, ...
# Music, Movies and Audio Books                                          [Movie DVD]
# TV and Video                     [Televisions, VCD & DVD, Home Theater System, ...
# Name: Subcategory, dtype: object

# %% [markdown]
# ### 4). EDA on Exchange Table:-

# %%
Exchange.head()
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
Exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %% [markdown]
# #### ✔️ Check the data types of columns :-

# %%
Exchange.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %% [markdown]
# #### 🛠️ Fix the data types of Date columns :-

# %%
Exchange['Date'] = pd.to_datetime(Exchange['Date'])

# %%
Exchange.dtypes
# Out:
# Date        datetime64[ns]
# Currency            object
# Exchange           float64
# dtype: object

# %%
Exchange.head()
# Out:
#         Date Currency  Exchange
# 0 2015-01-01      USD    1.0000
# 1 2015-01-01      CAD    1.1583
# 2 2015-01-01      AUD    1.2214
# 3 2015-01-01      EUR    0.8237
# 4 2015-01-01      GBP    0.6415

# %%
Exchange.to_csv(r'C:\Users\Rohit kumar\Downloads\Exchange.csv')

# %% [markdown]
# ### 5). EDA on Store Table:-

# %%
Stores.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0   1/1/2008
# 1         2  Australia            Northern Territory          665.0  1/12/2008
# 2         3  Australia               South Australia         2000.0   1/7/2012
# 3         4  Australia                      Tasmania         2000.0   1/1/2010
# 4         5  Australia                      Victoria         2000.0  12/9/2015

# %%
# Out:
# StoreKey           int64
# Country           object
# State             object
# Square Meters    float64
# Open Date         object
# dtype: object

# %% [markdown]
# #### ✔️ Check the data types of columns :-

# %%
Stores.dtypes
# Out:
# StoreKey           int64
# Country           object
# State             object
# Square Meters    float64
# Open Date         object
# dtype: object

# %% [markdown]
# #### 🛠️ Fix the data types of Date columns :-

# %%
Stores['Open Date'] = pd.to_datetime(Stores['Open Date'])

# %%
Stores.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters           float64
# Open Date        datetime64[ns]
# dtype: object

# %%
Stores.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0 2008-01-01
# 1         2  Australia            Northern Territory          665.0 2008-01-12
# 2         3  Australia               South Australia         2000.0 2012-01-07
# 3         4  Australia                      Tasmania         2000.0 2010-01-01
# 4         5  Australia                      Victoria         2000.0 2015-12-09

# %%
Stores.shape
# Out:
# (67, 5)

# %% [markdown]
# ### Now save csv file :-

# %%
Stores.to_csv(r'C:\Users\Rohit kumar\Downloads\store.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 Stores.to_csv(r'C:\Users\Rohit kumar\Downloads\store.csv')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
product.to_csv(r'C:\Users\Rohit kumar\Downloads\Product.csv')

# %%
product.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
Exchange.to_csv(r'C:\Users\Rohit kumar\Downloads\Exchange.csv')

# %%
sales.to_csv(r'C:\Users\Rohit kumar\Downloads\sales.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sales.to_csv(r'C:\Users\Rohit kumar\Downloads\sales.csv')
#
# NameError: name 'sales' is not defined

# %%
cust.to_csv(r'C:\Users\Rohit kumar\Downloads\customer.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 cust.to_csv(r'C:\Users\Rohit kumar\Downloads\customer.csv')
#
# NameError: name 'cust' is not defined
